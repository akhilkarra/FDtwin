# %% [markdown]
# # BLIP-2 Experiments
#
# This notebook contains the setup, input, and results of the experiments done on the BLIP-2 open-source LLM, taking the banana images from the Drive as input.
#
# Firstly, we need to set up BLIP-2's API and interface. The instructions are linked here: https://huggingface.co/blog/blip-2

# %%
# We will import BLIP-2 through the Hugging Face Transformers Git repo
# !pip3 install git+https://github.com/huggingface/transformers.git
# !pip3 install --upgrade torch
# !pip3 install --upgrade pytorch
# !pip3 install --upgrade transformers
# !pip3 install --upgrade pytorch-transformers
# !pip3 install --upgrade accelerate
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-c3g5ytkj
#   Running command git clone -q https://github.com/huggingface/transformers.git /tmp/pip-req-build-c3g5ytkj
# done
# done
# done
# Requirement already satisfied (use --upgrade to upgrade): transformers==4.31.0.dev0 from git+https://github.com/huggingface/transformers.git in /anaconda/envs/azureml_py38/lib/python3.8/site-packages
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (0.13.3)
# Requirement already satisfied: numpy>=1.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (2023.5.5)
# Requirement already satisfied: pyyaml>=5.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (0.14.1)
# Requirement already satisfied: requests in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (2.31.0)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (4.65.0)
# Requirement already satisfied: filelock in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (3.12.0)
# Requirement already satisfied: safetensors>=0.3.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers==4.31.0.dev0) (0.3.1)
# Requirement already satisfied: fsspec in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0.dev0) (2023.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0.dev0) (4.6.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->transformers==4.31.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->transformers==4.31.0.dev0) (2022.9.24)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->transformers==4.31.0.dev0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->transformers==4.31.0.dev0) (3.4)
# Building wheels for collected packages: transformers
# done
#   Created wheel for transformers: filename=transformers-4.31.0.dev0-py3-none-any.whl size=7348189 sha256=e4b7ce7e481cf95a79a6b42249a379a7bd9cdf1d2d00eda0f5e804a3d283213a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-29_skf8y/wheels/05/0a/97/64ae47c27ba95fae2cb5838e7b4b7247a34d4a8ba5f7092de2
# Successfully built transformers
# Requirement already up-to-date: torch in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (2.0.1)
# Requirement already satisfied, skipping upgrade: typing-extensions in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (4.6.0)
# Requirement already satisfied, skipping upgrade: triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (2.0.0)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (11.7.99)
# Requirement already satisfied, skipping upgrade: nvidia-cusolver-cu11==11.4.0.1; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied, skipping upgrade: filelock in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (3.12.0)
# Requirement already satisfied, skipping upgrade: jinja2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (2.11.2)
# Requirement already satisfied, skipping upgrade: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied, skipping upgrade: nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied, skipping upgrade: sympy in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (1.12)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (11.7.99)
# Requirement already satisfied, skipping upgrade: nvidia-cufft-cu11==10.9.0.58; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied, skipping upgrade: nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (11.7.91)
# Requirement already satisfied, skipping upgrade: nvidia-nccl-cu11==2.14.3; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (2.14.3)
# Requirement already satisfied, skipping upgrade: nvidia-cusparse-cu11==11.7.4.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied, skipping upgrade: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-cupti-cu11==11.7.101; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (11.7.101)
# Requirement already satisfied, skipping upgrade: networkx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch) (2.5)
# Requirement already satisfied, skipping upgrade: cmake in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch) (3.26.4)
# Requirement already satisfied, skipping upgrade: lit in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch) (16.0.6)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied, skipping upgrade: setuptools in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64"->torch) (65.6.3)
# Requirement already satisfied, skipping upgrade: wheel in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64"->torch) (0.37.1)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from networkx->torch) (5.1.1)
# Collecting pytorch
#   Using cached pytorch-1.0.2.tar.gz (689 bytes)
# Building wheels for collected packages: pytorch
# error
#   ERROR: Command errored out with exit status 1:
#    command: /anaconda/envs/azureml_py38/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-oi5af77u/pytorch/setup.py'"'"'; __file__='"'"'/tmp/pip-install-oi5af77u/pytorch/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-u_bhuwby
#        cwd: /tmp/pip-install-oi5af77u/pytorch/
#   Complete output (5 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-oi5af77u/pytorch/setup.py", line 15, in <module>
#       raise Exception(message)
#   Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#   ----------------------------------------
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# Installing collected packages: pytorch
# error
#     ERROR: Command errored out with exit status 1:
#      command: /anaconda/envs/azureml_py38/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-oi5af77u/pytorch/setup.py'"'"'; __file__='"'"'/tmp/pip-install-oi5af77u/pytorch/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-kth_od1h/install-record.txt --single-version-externally-managed --compile --install-headers /anaconda/envs/azureml_py38/include/python3.8/pytorch
#          cwd: /tmp/pip-install-oi5af77u/pytorch/
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-oi5af77u/pytorch/setup.py", line 11, in <module>
#         raise Exception(message)
#     Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /anaconda/envs/azureml_py38/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-oi5af77u/pytorch/setup.py'"'"'; __file__='"'"'/tmp/pip-install-oi5af77u/pytorch/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-kth_od1h/install-record.txt --single-version-externally-managed --compile --install-headers /anaconda/envs/azureml_py38/include/python3.8/pytorch Check the logs for full command output.
# Requirement already up-to-date: transformers in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (4.31.0.dev0)
# Requirement already satisfied, skipping upgrade: requests in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (2.31.0)
# Requirement already satisfied, skipping upgrade: tokenizers!=0.11.3,<0.14,>=0.11.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (0.13.3)
# Requirement already satisfied, skipping upgrade: huggingface-hub<1.0,>=0.14.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (0.14.1)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (23.0)
# Requirement already satisfied, skipping upgrade: safetensors>=0.3.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (0.3.1)
# Requirement already satisfied, skipping upgrade: pyyaml>=5.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (6.0)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (2023.5.5)
# Requirement already satisfied, skipping upgrade: filelock in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (3.12.0)
# Requirement already satisfied, skipping upgrade: tqdm>=4.27 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (4.65.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from transformers) (1.21.6)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.0)
# Requirement already satisfied, skipping upgrade: fsspec in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.5.0)
# Requirement already up-to-date: pytorch-transformers in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (1.2.0)
# Requirement already satisfied, skipping upgrade: torch>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pytorch-transformers) (2.0.1)
# Requirement already satisfied, skipping upgrade: sacremoses in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pytorch-transformers) (0.0.53)
# Requirement already satisfied, skipping upgrade: requests in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pytorch-transformers) (2.31.0)
# Requirement already satisfied, skipping upgrade: tqdm in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pytorch-transformers) (4.65.0)
# Requirement already satisfied, skipping upgrade: boto3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pytorch-transformers) (1.20.19)
# Requirement already satisfied, skipping upgrade: sentencepiece in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pytorch-transformers) (0.1.99)
# Requirement already satisfied, skipping upgrade: numpy in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pytorch-transformers) (1.21.6)
# Requirement already satisfied, skipping upgrade: regex in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pytorch-transformers) (2023.5.5)
# Requirement already satisfied, skipping upgrade: nvidia-nccl-cu11==2.14.3; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (2.14.3)
# Requirement already satisfied, skipping upgrade: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (8.5.0.96)
# Requirement already satisfied, skipping upgrade: nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (10.2.10.91)
# Requirement already satisfied, skipping upgrade: filelock in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (3.12.0)
# Requirement already satisfied, skipping upgrade: nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (11.7.91)
# Requirement already satisfied, skipping upgrade: jinja2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (2.11.2)
# Requirement already satisfied, skipping upgrade: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (11.10.3.66)
# Requirement already satisfied, skipping upgrade: nvidia-cufft-cu11==10.9.0.58; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (10.9.0.58)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-cupti-cu11==11.7.101; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (11.7.101)
# Requirement already satisfied, skipping upgrade: nvidia-cusparse-cu11==11.7.4.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (11.7.4.91)
# Requirement already satisfied, skipping upgrade: triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (2.0.0)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (11.7.99)
# Requirement already satisfied, skipping upgrade: nvidia-cusolver-cu11==11.4.0.1; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (11.4.0.1)
# Requirement already satisfied, skipping upgrade: typing-extensions in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (4.6.0)
# Requirement already satisfied, skipping upgrade: sympy in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (1.12)
# Requirement already satisfied, skipping upgrade: networkx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (2.5)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.0.0->pytorch-transformers) (11.7.99)
# Requirement already satisfied, skipping upgrade: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from sacremoses->pytorch-transformers) (1.16.0)
# Requirement already satisfied, skipping upgrade: joblib in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from sacremoses->pytorch-transformers) (1.2.0)
# Requirement already satisfied, skipping upgrade: click in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from sacremoses->pytorch-transformers) (8.1.3)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->pytorch-transformers) (3.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->pytorch-transformers) (2022.9.24)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->pytorch-transformers) (3.1.0)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->pytorch-transformers) (1.26.16)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from boto3->pytorch-transformers) (0.10.0)
# Requirement already satisfied, skipping upgrade: s3transfer<0.6.0,>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from boto3->pytorch-transformers) (0.5.2)
# Requirement already satisfied, skipping upgrade: botocore<1.24.0,>=1.23.19 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from boto3->pytorch-transformers) (1.23.19)
# Requirement already satisfied, skipping upgrade: wheel in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.0.0->pytorch-transformers) (0.37.1)
# Requirement already satisfied, skipping upgrade: setuptools in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.0.0->pytorch-transformers) (65.6.3)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jinja2->torch>=1.0.0->pytorch-transformers) (2.0.1)
# Requirement already satisfied, skipping upgrade: lit in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.0.0->pytorch-transformers) (16.0.6)
# Requirement already satisfied, skipping upgrade: cmake in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.0.0->pytorch-transformers) (3.26.4)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from sympy->torch>=1.0.0->pytorch-transformers) (1.3.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from networkx->torch>=1.0.0->pytorch-transformers) (5.1.1)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from botocore<1.24.0,>=1.23.19->boto3->pytorch-transformers) (2.8.2)
# Requirement already up-to-date: accelerate in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (0.20.3)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from accelerate) (23.0)
# Requirement already satisfied, skipping upgrade: psutil in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied, skipping upgrade: torch>=1.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from accelerate) (2.0.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from accelerate) (1.21.6)
# Requirement already satisfied, skipping upgrade: pyyaml in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from accelerate) (6.0)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (11.7.99)
# Requirement already satisfied, skipping upgrade: nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (11.7.91)
# Requirement already satisfied, skipping upgrade: triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (2.0.0)
# Requirement already satisfied, skipping upgrade: filelock in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (3.12.0)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-cupti-cu11==11.7.101; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (11.7.101)
# Requirement already satisfied, skipping upgrade: nvidia-cusparse-cu11==11.7.4.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (11.7.4.91)
# Requirement already satisfied, skipping upgrade: typing-extensions in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (4.6.0)
# Requirement already satisfied, skipping upgrade: nvidia-cusolver-cu11==11.4.0.1; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (11.4.0.1)
# Requirement already satisfied, skipping upgrade: nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (10.2.10.91)
# Requirement already satisfied, skipping upgrade: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (8.5.0.96)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (11.7.99)
# Requirement already satisfied, skipping upgrade: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (11.10.3.66)
# Requirement already satisfied, skipping upgrade: networkx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (2.5)
# Requirement already satisfied, skipping upgrade: nvidia-cufft-cu11==10.9.0.58; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (10.9.0.58)
# Requirement already satisfied, skipping upgrade: sympy in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (1.12)
# Requirement already satisfied, skipping upgrade: jinja2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (2.11.2)
# Requirement already satisfied, skipping upgrade: nvidia-nccl-cu11==2.14.3; platform_system == "Linux" and platform_machine == "x86_64" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from torch>=1.6.0->accelerate) (2.14.3)
# Requirement already satisfied, skipping upgrade: wheel in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.6.0->accelerate) (0.37.1)
# Requirement already satisfied, skipping upgrade: setuptools in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.6.0->accelerate) (65.6.3)
# Requirement already satisfied, skipping upgrade: cmake in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.6.0->accelerate) (3.26.4)
# Requirement already satisfied, skipping upgrade: lit in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.6.0->accelerate) (16.0.6)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from networkx->torch>=1.6.0->accelerate) (5.1.1)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jinja2->torch>=1.6.0->accelerate) (2.0.1)

# %%
import requests
from PIL import Image

cavendish_banana_1_img = Image.open('./annotated-images/Cavendish-banana--1-_jpg.rf.2e9bf7467f538a9637bae28c4e0b2a70.jpg').convert('RGB')
display(cavendish_banana_1_img)
thep_phanom_7_img = Image.open('./annotated-images/thepphanom--7-_jpg.rf.3cd347d770e03c8839ab7d6cf565292a.jpg').convert('RGB')
display(thep_phanom_7_img)
cultivated_banana_2_img = Image.open('./annotated-images/cultivated-banana--2-_jpg.rf.e0646ebe05d265eeaf65eafb474bc1d2.jpg').convert('RGB')
display(cultivated_banana_2_img)
# Out:
# <PIL.Image.Image image mode=RGB size=554x739>
# <PIL.Image.Image image mode=RGB size=300x200>
# <PIL.Image.Image image mode=RGB size=554x739>

# %%
import torch
# This block will ensures the code runs on the GPU if available
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# We need to set up a preprocessor to process the input to satisfy BLIP-2's
# required parameters. We also need to import the model itself
from transformers import AutoProcessor, Blip2ForConditionalGeneration

processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", torch_dtype=torch.float16)
model.to(device)
# Out:
# 2023-07-12 15:19:35.075323: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-12 15:19:55.796354: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-07-12 15:19:55.796478: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-07-12 15:19:55.796491: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Blip2ForConditionalGeneration(
#   (vision_model): Blip2VisionModel(
#     (embeddings): Blip2VisionEmbeddings(
#       (patch_embedding): Conv2d(3, 1408, kernel_size=(14, 14), stride=(14, 14))
#     )
#     (encoder): Blip2Encoder(
#       (layers): ModuleList(
#         (0-38): 39 x Blip2EncoderLayer(
#           (self_attn): Blip2Attention(
#             (dropout): Dropout(p=0.0, inplace=False)
#             (qkv): Linear(in_features=1408, out_features=4224, bias=True)
#             (projection): Linear(in_features=1408, out_features=1408, bias=True)
#           )
#           (layer_norm1): LayerNorm((1408,), eps=1e-05, elementwise_affine=True)
#           (mlp): Blip2MLP(
#             (activation_fn): GELUActivation()
#             (fc1): Linear(in_features=1408, out_features=6144, bias=True)
#             (fc2): Linear(in_features=6144, out_features=1408, bias=True)
#           )
#           (layer_norm2): LayerNorm((1408,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((1408,), eps=1e-05, elementwise_affine=True)
#   )
#   (qformer): Blip2QFormerModel(
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (encoder): Blip2QFormerEncoder(
#       (layer): ModuleList(
#         (0): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (language_projection): Linear(in_features=768, out_features=2560, bias=True)
#   (language_model): OPTForCausalLM(
#     (model): OPTModel(
#       (decoder): OPTDecoder(
#         (embed_tokens): Embedding(50272, 2560, padding_idx=1)
#         (embed_positions): OPTLearnedPositionalEmbedding(2050, 2560)
#         (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (layers): ModuleList(
#           (0-31): 32 x OPTDecoderLayer(
#             (self_attn): OPTAttention(
#               (k_proj): Linear(in_features=2560, out_features=2560, bias=True)
#               (v_proj): Linear(in_features=2560, out_features=2560, bias=True)
#               (q_proj): Linear(in_features=2560, out_features=2560, bias=True)
#               (out_proj): Linear(in_features=2560, out_features=2560, bias=True)
#             )
#             (activation_fn): ReLU()
#             (self_attn_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=2560, out_features=10240, bias=True)
#             (fc2): Linear(in_features=10240, out_features=2560, bias=True)
#             (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=2560, out_features=50272, bias=False)
#   )
# )

# %%
# Asking BLIP-2 questions about each banana
def ask_a_question(question, banana_file):
    inputs = processor(banana_file, text=question, return_tensors="pt").to(device, torch.float16)
    generated_ids = model.generate(**inputs, max_new_tokens=20)
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
    print(question, generated_text)

def asking_questions(banana_file):
    ask_a_question("Question: Describe the input image. Answer:", banana_file)
    ask_a_question("Question: Is the banana in the image green? Answer:", banana_file)
    ask_a_question("Question: Is the banana in the image yellow? Answer:", banana_file)
    # ask_a_question("Question: Is the banana brown? Answer:", banana_file)
    # ask_a_question("Question: Is the banana black? Answer:", banana_file)
    ask_a_question("Question: Are there brown spots on the banana in the image? Answer:", banana_file)
    ask_a_question("Question: Describe the input image. Answer:", banana_file)
    ask_a_question("Question: Looking at just the outer skin of the banana, does the banana in the input image have brown patches? Answer:", banana_file)
    ask_a_question("Question: Do the bananas look healthy? Answer:", banana_file)
    ask_a_question("Question: Is this banana going to be tasty to eat? Answer:", banana_file)
    ask_a_question("Question: Is there any mold on this banana? Answer:", banana_file)
    ask_a_question("Question: How do you know if a banana has been sprayed with pesticides? Answer:", banana_file)
    ask_a_question("Question: Is this banana in the input image ripe? Answer:", banana_file)

print("Thep phanom 7:")
asking_questions(thep_phanom_7_img)

print("\nCavendish banana 1:")
asking_questions(cavendish_banana_1_img)

print("\nCultivated banana 2:")
asking_questions(cultivated_banana_2_img)
# Out:
# Thep phanom 7:
# Question: Describe the input image. Answer: a banana
# Question: Is the banana in the image green? Answer: Yes, it is green
# Question: Is the banana in the image yellow? Answer: No, it is green
# Question: Are there brown spots on the banana in the image? Answer: No, the banana is not brown
# Question: Describe the input image. Answer: a banana
# Question: Looking at just the outer skin of the banana, does the banana in the input image have brown patches? Answer: Yes, the banana in the input image has brown patches
# Question: Do the bananas look healthy? Answer: Yes, they look healthy
# Question: Is this banana going to be tasty to eat? Answer: No
# Question: Is there any mold on this banana? Answer: No, there is no mold on this banana
# Question: How do you know if a banana has been sprayed with pesticides? Answer: You don't
# Question: Is this banana in the input image ripe? Answer: No
#
# Cavendish banana 1:
# Question: Describe the input image. Answer: A bunch of bananas
# Question: Is the banana in the image green? Answer: No, it is yellow
# Question: Is the banana in the image yellow? Answer: Yes
# Question: Are there brown spots on the banana in the image? Answer: Yes, there are brown spots on the banana in the image
# Question: Describe the input image. Answer: A bunch of bananas
# Question: Looking at just the outer skin of the banana, does the banana in the input image have brown patches? Answer: Yes
# Question: Do the bananas look healthy? Answer: Yes, they look healthy
# Question: Is this banana going to be tasty to eat? Answer: Yes, it is
# Question: Is there any mold on this banana? Answer: No, there is no mold on this banana
# Question: How do you know if a banana has been sprayed with pesticides? Answer: You don't.
# Question: Is this banana in the input image ripe? Answer: Yes
#
# Cultivated banana 2:
# Question: Describe the input image. Answer: The banana is brown and has a black spot on the top
# Question: Is the banana in the image green? Answer: No, it is not green
# Question: Is the banana in the image yellow? Answer: No, it is not yellow
# Question: Are there brown spots on the banana in the image? Answer: Yes, there are brown spots on the banana in the image
# Question: Describe the input image. Answer: The banana is brown and has a black spot on the top
# Question: Looking at just the outer skin of the banana, does the banana in the input image have brown patches? Answer: Yes, the banana in the input image has brown patches
# Question: Do the bananas look healthy? Answer: No, they look like they have been sprayed with pesticides
# Question: Is this banana going to be tasty to eat? Answer: No
# Question: Is there any mold on this banana? Answer: No, there is no mold on this banana
# Question: How do you know if a banana has been sprayed with pesticides? Answer: You don't
# Question: Is this banana in the input image ripe? Answer: No

# %%
# Running the model on Cavendish-banana--1-_jpg WITH context
context = [
   ("When will a green banana be ripe?", "7 days"),
   ("When will a yellow banana with no spots be ripe?", "5 days"),
   ("When will a yellow banana with some brown spots be ripe?", "3 days"),
   ("When will a yellow banana with a brown patches be ripe?", "1 day"),
   ("When will a yellow banana with a couple brown patches be ripe?", "it is already ripe"),
   ("When will a brown banana be ripe?", "it is overripe"),
   ("When will a black banana be ripe?", "it is very overripe")
]
question = "How many days will it take for this banana to be fully ripe?"
template = "Question: {} Answer: {}."

prompt = " ".join([template.format(context[i][0], context[i][1]) for i in range(len(context))]) + " Question: " + question + " Answer:"

inputs = processor(cavendish_banana_1_img, text=prompt, return_tensors="pt").to(device, torch.float16)

generated_ids = model.generate(**inputs, max_new_tokens=20)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
print("output:", generated_text)
# Out:
# output: it will be fully ripe in 1 day. Question: How many days will it take for this banana

# %%
# Running the model on Cavendish-banana--1-_jpg WITHOUT context
context = []
question = "How many days will it take for this banana to be fully ripe?"
template = "Question: {} Answer: {}."

prompt = " ".join([template.format(context[i][0], context[i][1]) for i in range(len(context))]) + " Question: " + question + " Answer:"

inputs = processor(cavendish_banana_1_img, text=prompt, return_tensors="pt").to(device, torch.float16)

generated_ids = model.generate(**inputs, max_new_tokens=20)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
print("output:", generated_text)
# Out:
# output: 7 days

# %%
# Running the model on Cavendish-banana--1-_jpg WITH MINIMAL context
context = [
    ("","")
]
question = "What food item is this? How many days will it take for this food item to be fully ripe?"
template = "Question: {} Answer: {}."

prompt = " ".join([template.format(context[i][0], context[i][1]) for i in range(len(context))]) + " Question: " + question + " Answer:"

inputs = processor(cavendish_banana_1_img, text=prompt, return_tensors="pt").to(device, torch.float16)

generated_ids = model.generate(**inputs, max_new_tokens=20)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
print("output:", generated_text)

# %%
# Running the model on Thep-phanom-7-_jpg WITH context
# context = []
context = [
   ("When will a green banana be ripe?", "7 days"),
   ("When will a yellow banana with no spots be ripe?", "5 days"),
   ("When will a yellow banana with some brown spots be ripe?", "3 days"),
   ("When will a yellow banana with a brown patches be ripe?", "1 day"),
   ("When will a yellow banana with a couple brown patches be ripe?", "it is already ripe"),
   ("When will a brown banana be ripe?", "it is overripe"),
   ("When will a black banana be ripe?", "it is very overripe")
]
question = "How many days will it take for this banana to be fully ripe?"
template = "Question: {} Answer: {}."

prompt = " ".join([template.format(context[i][0], context[i][1]) for i in range(len(context))]) + " Question: " + question + " Answer:"

inputs = processor(thep_phanom_7_img, text=prompt, return_tensors="pt").to(device, torch.float16)

generated_ids = model.generate(**inputs, max_new_tokens=20)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
print("output:", generated_text)
# Out:
# output: it will take 7 days. Question: How many days will it take for this banana to be fully

# %%
# Running the model on Thep-phanom-7-_jpg WITHOUT context
# context = []
context = []
question = "How many days will it take for this banana to be fully ripe?"
template = "Question: {} Answer: {}."

prompt = " ".join([template.format(context[i][0], context[i][1]) for i in range(len(context))]) + " Question: " + question + " Answer:"

inputs = processor(thep_phanom_7_img, text=prompt, return_tensors="pt").to(device, torch.float16)

generated_ids = model.generate(**inputs, max_new_tokens=20)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
print("output:", generated_text)
# Out:
# output: It depends on the weather

# %%
# Running the model on cultivated_banana_2.img WITH context
context = [
   ("When will a green banana be ripe?", "7 days"),
   ("When will a yellow banana with no spots be ripe?", "5 days"),
   ("When will a yellow banana with some brown spots be ripe?", "3 days"),
   ("When will a yellow banana with a brown patches be ripe?", "1 day"),
   ("When will a yellow banana with a couple brown patches be ripe?", "it is already ripe"),
   ("When will a brown banana be ripe?", "it is overripe"),
   ("When will a black banana be ripe?", "it is very overripe")
]
# question = "How many days will it take for this banana to be fully ripe?"
question = "How many days will it take for this banana to be fully ripe"
template = "Question: {} Answer: {}."

prompt = " ".join([template.format(context[i][0], context[i][1]) for i in range(len(context))]) + " Question: " + question + " Answer:"

inputs = processor(cultivated_banana_2_img, text=prompt, return_tensors="pt").to(device, torch.float16)

generated_ids = model.generate(**inputs, max_new_tokens=20)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
print("output:", generated_text)
# Out:
# output: it will take about 7 days. Question: How many days will it take for this banana to be

# %%
# Running the model on cultivated_banana_2.img WITHOUT context
context = []
# question = "How many days will it take for this banana to be fully ripe?"
question = "How many days will it take for this banana to be fully ripe"
template = "Question: {} Answer: {}."

prompt = " ".join([template.format(context[i][0], context[i][1]) for i in range(len(context))]) + " Question: " + question + " Answer:"

inputs = processor(cultivated_banana_2_img, text=prompt, return_tensors="pt").to(device, torch.float16)

generated_ids = model.generate(**inputs, max_new_tokens=20)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
print("output:", generated_text)
# Out:
# output: It depends on the weather and the temperature
