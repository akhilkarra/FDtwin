# %% [markdown]
# # Initial Experiments with ChatGPT
#
# Here we conduct some experiments on ChatGPT alone given some textual inputs.
#
# Although GPT-4 now supports image input, obtaining access is proving to be quite difficult. So one idea we have is to let BLIP-2 or some similar model give as much description of the input image as possible and then feed ChatGPT all of this context. Then we let ChatGPT describe when the bananas will be ripe and when they will expire.

# %%
# !pip3 install --upgrade openai
# !pip3 install --upgrade azure-keyvault-secrets
# !pip3 install --upgrade azure-cli
# !pip3 install --upgrade azure-identity
# Out:
# Requirement already up-to-date: openai in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (0.27.8)
# Requirement already satisfied, skipping upgrade: aiohttp in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from openai) (3.8.4)
# Requirement already satisfied, skipping upgrade: tqdm in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from openai) (4.64.1)
# Requirement already satisfied, skipping upgrade: requests>=2.20 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from openai) (2.28.2)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4.0,>=2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from aiohttp->openai) (3.0.1)
# Requirement already satisfied, skipping upgrade: aiosignal>=1.1.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from aiohttp->openai) (22.2.0)
# Requirement already satisfied, skipping upgrade: multidict<7.0,>=4.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied, skipping upgrade: frozenlist>=1.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied, skipping upgrade: async-timeout<5.0,>=4.0.0a3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.20->openai) (2022.9.24)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already up-to-date: azure-keyvault-secrets in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (4.7.0)
# Requirement already satisfied, skipping upgrade: azure-common~=1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-keyvault-secrets) (1.1.28)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-keyvault-secrets) (0.6.1)
# Requirement already satisfied, skipping upgrade: azure-core<2.0.0,>=1.24.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-keyvault-secrets) (1.26.3)
# Requirement already satisfied, skipping upgrade: typing-extensions>=4.0.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-keyvault-secrets) (4.4.0)
# Requirement already satisfied, skipping upgrade: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from isodate>=0.6.1->azure-keyvault-secrets) (1.16.0)
# Requirement already satisfied, skipping upgrade: requests>=2.18.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-core<2.0.0,>=1.24.0->azure-keyvault-secrets) (2.28.2)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-keyvault-secrets) (1.26.14)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-keyvault-secrets) (2022.9.24)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-keyvault-secrets) (3.4)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-keyvault-secrets) (3.0.1)
# Requirement already up-to-date: azure-cli in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (2.50.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-managementgroups~=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: PyGithub~=1.38 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.58.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-databoxedge~=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: jsondiff~=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied, skipping upgrade: azure-multiapi-storage~=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.2.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-billing==6.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (6.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-datalake-analytics~=0.2.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.2.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-monitor~=5.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (5.0.1)
# Requirement already satisfied, skipping upgrade: scp~=0.13.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.13.6)
# Requirement already satisfied, skipping upgrade: azure-mgmt-applicationinsights~=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-media~=9.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage~=21.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (21.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-hdinsight~=9.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-iothubprovisioningservices==1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-msi~=7.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (7.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerinstance==10.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.1.0)
# Requirement already satisfied, skipping upgrade: javaproperties~=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.5.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-appcontainers==2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-netapp~=10.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-iotcentral~=10.0.0b1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.0.0b2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization~=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-managedservices~=1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: azure-keyvault~=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-security==3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-extendedlocation==1.0.0b2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0b2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-apimanagement==4.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied, skipping upgrade: azure-keyvault-certificates==4.7.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (4.7.0)
# Requirement already satisfied, skipping upgrade: azure-synapse-managedprivateendpoints~=0.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.4.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-cognitiveservices~=13.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (13.3.0)
# Requirement already satisfied, skipping upgrade: antlr4-python3-runtime~=4.9.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (4.9.3)
# Requirement already satisfied, skipping upgrade: semver==2.13.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.13.0)
# Requirement already satisfied, skipping upgrade: urllib3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.26.14)
# Requirement already satisfied, skipping upgrade: azure-mgmt-servicelinker==1.2.0b1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.2.0b1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry==10.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-kusto~=0.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.3.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-servicefabricmanagedclusters~=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-relay~=0.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-servicefabric~=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-batch~=17.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (17.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-sqlvirtualmachine==1.0.0b5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0b5)
# Requirement already satisfied, skipping upgrade: azure-cli-core==2.50.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.50.0)
# Requirement already satisfied, skipping upgrade: azure-keyvault-secrets==4.7.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (4.7.0)
# Requirement already satisfied, skipping upgrade: PyNaCl~=1.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.5.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-datalake-store~=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.5.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-recoveryservicesbackup~=6.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (6.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerservice~=24.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (24.0.0)
# Requirement already satisfied, skipping upgrade: azure-keyvault-keys==4.8.0b2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (4.8.0b2)
# Requirement already satisfied, skipping upgrade: azure-keyvault-administration==4.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (4.3.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-redhatopenshift~=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.2.0)
# Requirement already satisfied, skipping upgrade: colorama~=0.4.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.4.6)
# Requirement already satisfied, skipping upgrade: azure-mgmt-marketplaceordering==1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-trafficmanager~=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: chardet~=3.0.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (3.0.4)
# Requirement already satisfied, skipping upgrade: azure-mgmt-cosmosdb==9.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (9.2.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-redis~=14.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (14.1.0)
# Requirement already satisfied, skipping upgrade: fabric~=2.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.7.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-botservice~=2.0.0b3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-loganalytics==13.0.0b4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (13.0.0b4)
# Requirement already satisfied, skipping upgrade: azure-mgmt-web==7.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (7.0.0)
# Requirement already satisfied, skipping upgrade: azure-synapse-spark~=0.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.2.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-compute~=29.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (29.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-privatedns~=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-eventhub~=10.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-search~=9.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-servicebus~=8.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (8.2.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-eventgrid==10.2.0b2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.2.0b2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-maps~=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied, skipping upgrade: distro; sys_platform == "linux" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.8.0)
# Requirement already satisfied, skipping upgrade: azure-synapse-accesscontrol~=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.5.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-advisor==9.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-iothub==2.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.3.0)
# Requirement already satisfied, skipping upgrade: azure-cosmos>=3.0.2,~=3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (3.2.0)
# Requirement already satisfied, skipping upgrade: azure-graphrbac~=0.60.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.60.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource==23.1.0b2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (23.1.0b2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-appconfiguration==3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-policyinsights~=1.1.0b2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.1.0b4)
# Requirement already satisfied, skipping upgrade: azure-mgmt-recoveryservices~=2.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.4.0)
# Requirement already satisfied, skipping upgrade: azure-synapse-artifacts~=0.15.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.15.0)
# Requirement already satisfied, skipping upgrade: sshtunnel~=0.1.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.1.5)
# Requirement already satisfied, skipping upgrade: azure-mgmt-sql==4.0.0b10 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (4.0.0b10)
# Requirement already satisfied, skipping upgrade: azure-storage-common~=1.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.4.2)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.16.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-synapse==2.1.0b5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.1.0b5)
# Requirement already satisfied, skipping upgrade: azure-mgmt-cdn==12.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (12.0.0)
# Requirement already satisfied, skipping upgrade: azure-datalake-store~=0.0.49 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.0.52)
# Requirement already satisfied, skipping upgrade: azure-mgmt-rdbms~=10.2.0b10 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.2.0b10)
# Requirement already satisfied, skipping upgrade: azure-mgmt-signalr==1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault==10.2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.2.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-batchai==7.0.0b1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (7.0.0b1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-devtestlabs~=4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-dns~=8.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (8.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-datamigration~=10.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (10.0.0)
# Requirement already satisfied, skipping upgrade: azure-data-tables==12.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (12.4.0)
# Requirement already satisfied, skipping upgrade: azure-batch~=13.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (13.0.0)
# Requirement already satisfied, skipping upgrade: packaging>=20.9 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (21.3)
# Requirement already satisfied, skipping upgrade: azure-appconfiguration~=1.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.1.1)
# Requirement already satisfied, skipping upgrade: azure-mgmt-consumption~=2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied, skipping upgrade: websocket-client~=1.3.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.3.3)
# Requirement already satisfied, skipping upgrade: azure-loganalytics~=0.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.1.1)
# Requirement already satisfied, skipping upgrade: xmltodict~=0.12 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (0.13.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-imagebuilder~=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli) (1.2.0)
# Requirement already satisfied, skipping upgrade: msrest>=0.6.21 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-mgmt-managementgroups~=1.0.0->azure-cli) (0.7.1)
# Requirement already satisfied, skipping upgrade: azure-common~=1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-mgmt-managementgroups~=1.0.0->azure-cli) (1.1.28)
# Requirement already satisfied, skipping upgrade: azure-mgmt-core<2.0.0,>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-mgmt-managementgroups~=1.0.0->azure-cli) (1.3.2)
# Requirement already satisfied, skipping upgrade: deprecated in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from PyGithub~=1.38->azure-cli) (1.2.13)
# Requirement already satisfied, skipping upgrade: pyjwt[crypto]>=2.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from PyGithub~=1.38->azure-cli) (2.4.0)
# Requirement already satisfied, skipping upgrade: requests>=2.14.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from PyGithub~=1.38->azure-cli) (2.28.2)
# Requirement already satisfied, skipping upgrade: cryptography>=2.1.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-multiapi-storage~=1.2.0->azure-cli) (38.0.4)
# Requirement already satisfied, skipping upgrade: python-dateutil in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-multiapi-storage~=1.2.0->azure-cli) (2.8.2)
# Requirement already satisfied, skipping upgrade: azure-core<2.0.0,>=1.10.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-multiapi-storage~=1.2.0->azure-cli) (1.26.3)
# Requirement already satisfied, skipping upgrade: azure-mgmt-datalake-nspkg>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-mgmt-datalake-analytics~=0.2.1->azure-cli) (3.0.1)
# Requirement already satisfied, skipping upgrade: msrestazure<2.0.0,>=0.4.7 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-mgmt-datalake-analytics~=0.2.1->azure-cli) (0.6.4)
# Requirement already satisfied, skipping upgrade: paramiko in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scp~=0.13.2->azure-cli) (2.12.0)
# Requirement already satisfied, skipping upgrade: isodate<1.0.0,>=0.6.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-mgmt-containerinstance==10.1.0->azure-cli) (0.6.1)
# Requirement already satisfied, skipping upgrade: azure-nspkg>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-keyvault~=1.1.0->azure-cli) (3.0.2)
# Requirement already satisfied, skipping upgrade: typing-extensions>=4.0.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-keyvault-certificates==4.7.0->azure-cli) (4.4.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-nspkg>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-mgmt-relay~=0.1.0->azure-cli) (3.0.2)
# Requirement already satisfied, skipping upgrade: humanfriendly~=10.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (10.0)
# Requirement already satisfied, skipping upgrade: knack~=0.10.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (0.10.1)
# Requirement already satisfied, skipping upgrade: pyopenssl>=17.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (23.0.0)
# Requirement already satisfied, skipping upgrade: jmespath in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (0.10.0)
# Requirement already satisfied, skipping upgrade: msal-extensions~=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (1.0.0)
# Requirement already satisfied, skipping upgrade: argcomplete~=3.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (3.1.1)
# Requirement already satisfied, skipping upgrade: pkginfo>=1.5.0.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (1.9.6)
# Requirement already satisfied, skipping upgrade: azure-cli-telemetry==1.0.8.* in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (1.0.8)
# Requirement already satisfied, skipping upgrade: psutil~=5.9; sys_platform != "cygwin" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (5.9.4)
# Requirement already satisfied, skipping upgrade: msal[broker]==1.22.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-core==2.50.0->azure-cli) (1.22.0)
# Requirement already satisfied, skipping upgrade: cffi>=1.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from PyNaCl~=1.5.0->azure-cli) (1.15.1)
# Requirement already satisfied, skipping upgrade: invoke<2.0,>=1.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from fabric~=2.4->azure-cli) (1.7.3)
# Requirement already satisfied, skipping upgrade: pathlib2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from fabric~=2.4->azure-cli) (2.3.7.post1)
# Requirement already satisfied, skipping upgrade: adal>=0.4.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-datalake-store~=0.0.49->azure-cli) (1.2.7)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.5,>=2.0.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from packaging>=20.9->azure-cli) (3.0.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.6.21->azure-mgmt-managementgroups~=1.0.0->azure-cli) (2022.9.24)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.6.21->azure-mgmt-managementgroups~=1.0.0->azure-cli) (1.3.1)
# Requirement already satisfied, skipping upgrade: wrapt<2,>=1.10 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from deprecated->PyGithub~=1.38->azure-cli) (1.12.1)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.14.0->PyGithub~=1.38->azure-cli) (3.4)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests>=2.14.0->PyGithub~=1.38->azure-cli) (3.0.1)
# Requirement already satisfied, skipping upgrade: bcrypt>=3.1.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from paramiko->scp~=0.13.2->azure-cli) (4.0.1)
# Requirement already satisfied, skipping upgrade: pyyaml in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from knack~=0.10.1->azure-cli-core==2.50.0->azure-cli) (6.0)
# Requirement already satisfied, skipping upgrade: pygments in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from knack~=0.10.1->azure-cli-core==2.50.0->azure-cli) (2.14.0)
# Requirement already satisfied, skipping upgrade: tabulate in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from knack~=0.10.1->azure-cli-core==2.50.0->azure-cli) (0.9.0)
# Requirement already satisfied, skipping upgrade: portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msal-extensions~=1.0.0->azure-cli-core==2.50.0->azure-cli) (2.7.0)
# Requirement already satisfied, skipping upgrade: applicationinsights<0.12,>=0.11.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-cli-telemetry==1.0.8.*->azure-cli-core==2.50.0->azure-cli) (0.11.10)
# Requirement already satisfied, skipping upgrade: pycparser in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from cffi>=1.4.1->PyNaCl~=1.5.0->azure-cli) (2.21)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-mgmt-managementgroups~=1.0.0->azure-cli) (3.2.2)
# Requirement already up-to-date: azure-identity in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (1.13.0)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-identity) (1.16.0)
# Requirement already satisfied, skipping upgrade: msal<2.0.0,>=1.20.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-identity) (1.22.0)
# Requirement already satisfied, skipping upgrade: azure-core<2.0.0,>=1.11.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-identity) (1.26.3)
# Requirement already satisfied, skipping upgrade: msal-extensions<2.0.0,>=0.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-identity) (1.0.0)
# Requirement already satisfied, skipping upgrade: cryptography>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-identity) (38.0.4)
# Requirement already satisfied, skipping upgrade: PyJWT[crypto]<3,>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msal<2.0.0,>=1.20.0->azure-identity) (2.4.0)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msal<2.0.0,>=1.20.0->azure-identity) (2.28.2)
# Requirement already satisfied, skipping upgrade: typing-extensions>=4.0.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-core<2.0.0,>=1.11.0->azure-identity) (4.4.0)
# Requirement already satisfied, skipping upgrade: portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity) (2.7.0)
# Requirement already satisfied, skipping upgrade: cffi>=1.12 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from cryptography>=2.5->azure-identity) (1.15.1)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3,>=2.0.0->msal<2.0.0,>=1.20.0->azure-identity) (3.4)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3,>=2.0.0->msal<2.0.0,>=1.20.0->azure-identity) (3.0.1)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3,>=2.0.0->msal<2.0.0,>=1.20.0->azure-identity) (1.26.14)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3,>=2.0.0->msal<2.0.0,>=1.20.0->azure-identity) (2022.9.24)
# Requirement already satisfied, skipping upgrade: pycparser in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)

# %%
import openai
import logging
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient

# Azure Key Vault details
vault_url = 'https://elaida-key-vault.vault.azure.net/'
# !export KEY_VAULT_NAME=elaida-key-vault
credential = DefaultAzureCredential()

client = SecretClient(vault_url=vault_url, credential=credential)

# Secret in Azure Key Vault
secret_name = 'openai-api-key'

openai.organization = "org-dCBPowSQXeNf2LYmzFXboT3s"
api_key = client.get_secret(secret_name).value
openai.api_key = api_key

# %%
headers = {
    'Authorization': f'Bearer {api_key}',
    'Content-Type': 'application/json'
}

# Define your prompt
prompt = '''
Here is a lookup table to deduce how long it will take for a banana to get ripe. The format is (Question, Answer):
[
   ("When will a green banana be ripe?", "7 days"),
   ("When will a yellow banana with no spots be ripe?", "5 days"),
   ("When will a yellow banana with some brown spots be ripe?", "3 days"),
   ("When will a yellow banana with a brown patches be ripe?", "1 day"),
   ("When will a yellow banana with a couple brown patches be ripe?", "it is already ripe"),
   ("When will a brown banana be ripe?", "it is overripe"),
   ("When will a black banana be ripe?", "it is very overripe")
]

BLIP-2, a large language model (LLM) capable of taking image inputs, took an image of a banana as input. I asked BLIP-2 a series of questions, and then the LLM then generated the following text:
Question: Describe the input image. Answer: a banana
Question: Is the banana in the image green? Answer: Yes, it is green
Question: Is the banana in the image yellow? Answer: No, it is green
Question: Are there brown spots on the banana in the image? Answer: No, the banana is not brown
Question: Describe the input image. Answer: a banana
Question: Looking at just the outer skin of the banana, does the banana in the input image have brown patches? Answer: Yes, the banana in the input image has brown patches
Question: Do the bananas look healthy? Answer: Yes, they look healthy
Question: Is this banana going to be tasty to eat? Answer: No
Question: Is there any mold on this banana? Answer: No, there is no mold on this banana
Question: How do you know if a banana has been sprayed with pesticides? Answer: You don't
Question: Is this banana in the input image ripe? Answer: No

Given the above pieces of information, deduce how long it will take for the banana to fully ripen. Give your answer in two parts:
    First, fill in the blank with the appropriate integer: "The banana will be fully ripe in ___ days."
    Then provide a step-by-step explanation and deduction for the answer. This is meant to debug and understand the process you took to get to the answer, so please provide as much detail as you can.
'''

# Set the model and engine
model = 'gpt-3.5-turbo-16k'

# Create the data payload
data = {
    'prompt': prompt,
    'model': model
}

# Send the request to the API
completion = openai.ChatCompletion.create(
    model=model,
    messages=[
        {'role': 'user', 'content': prompt},
    ]
)

# Get the generated text from the response
generated_text = completion.choices[0].message

# Print the generated text
print(generated_text["content"])
# Out:
# The banana will be fully ripe in _7_ days.
#
# Explanation:
# Based on the information provided in the lookup table and the responses from BLIP-2, we can deduce the following:
#
# 1. The banana in the input image is described as "green" and does not have any brown spots. According to the lookup table, a green banana will be ripe in 7 days.
#
# BLIP-2 confirmed that the banana is not yet yellow, indicating that it is still in the early stages of ripening.
#
# 2. The banana in the input image has brown patches on the outer skin. According to the lookup table, a banana with brown patches will be ripe in 1 day.
#
# However, BLIP-2 also stated that the banana does not look healthy and will not be tasty to eat. This suggests that the brown patches might not be a result of ripening, but rather indicate some form of damage or unfavorable condition.
#
# 3. BLIP-2 also confirmed that there is no mold on the banana, which could further suggest that the brown patches are not a natural part of the ripening process.
#
# 4. BLIP-2 mentioned that you can't determine if a banana has been sprayed with pesticides, pointing out that there might be some concerns about the quality or safety of the banana.
#
# Combining all this information, we can conclude that the brown patches on the banana in the image are not a sign of ripeness but might indicate some form of damage or unfavorable condition. Since the banana is still green and not yet yellow, it is reasonable to assume that it is not yet ripe and will require the full 7 days for ripening, as mentioned in the lookup table.
#
# Therefore, the banana will be fully ripe in 7 days.
